# %%
import pandas as pd

# Correct URL for CSV export
url = "https://docs.google.com/spreadsheets/d/1i5SKBS7lr6nBPC2OTOF8Bj6sXiWAcKEj58Vg7ssdaKQ/export?format=csv"

# Read the CSV content into a DataFrame
df = pd.read_csv(url)

# Print the DataFrame
df.to_csv('data/processed/uploaded_files/input_data.csv',index=False)

# %%
df
# Out:
#     EMUL_OIL_L_TEMP_PV_VAL0  STAND_OIL_L_TEMP_PV_REAL_VAL0  \
# 0                 60.355865                      53.899261
# 1                 60.068710                      54.131332
# 2                 60.398239                      54.184143
# 3                 60.359528                      54.666901
# 4                 60.448059                      54.954453
# 5                 60.409119                      55.240479
# 6                 60.493835                      55.404556
# 7                 60.397598                      55.637772
# 8                 60.409500                      55.705780
# 9                 60.484039                      55.806091
# 10                60.327637                      55.950806
# 11                60.274857                      56.003906
# 12                60.219910                      56.051071
# 13                60.163727                      55.949265
# 14                60.327637                      55.950806
#
# ...
